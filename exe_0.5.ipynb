# %% [markdown]
# 05 - **Faça um programa que receba um número inteiro e verifique se esse número é par ou ímpar.**

# %%
x = int(input('Digite um número inteiro: \n'))

if x % 2 == 0:
  print(f'O número {x} é Par.')
else:
  print(f'O número {x} é Ímpar.')
